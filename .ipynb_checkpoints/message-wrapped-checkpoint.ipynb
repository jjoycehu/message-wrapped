# %% [markdown]
# had to change full disk access to allow terminal

# %% [markdown]
# credit: https://medium.com/@yaskalidis/heres-how-you-can-access-your-entire-imessage-history-on-your-mac-f8878276c6e9

# %%
import sqlite3
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
# %matplotlib inline
import re
import typedstream
import pickle

# %%
data = b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84\x84\x84\x19NSMutableAttributedString\x00\x84\x84\x12NSAttributedString\x00\x84\x84\x08NSObject\x00\x85\x92\x84\x84\x84\x0fNSMutableString\x01\x84\x84\x08NSString\x01\x95\x84\x01+\x11ahh oki thank you\x86\x84\x02iI\x01\x11\x92\x84\x84\x84\x0cNSDictionary\x00\x95\x84\x01i\x01\x92\x84\x98\x98\x1d__kIMMessagePartAttributeName\x86\x92\x84\x84\x84\x08NSNumber\x00\x84\x84\x07NSValue\x00\x95\x84\x01*\x84\x9b\x9b\x00\x86\x86\x86'
typedstream.unarchive_from_data(data)

# Unarchive the data
unarchived_data = typedstream.unarchive_from_data(data)

# Access the contents of the GenericArchivedObject
contents = unarchived_data.contents

contents[0].value.value
# Out:
# 'ahh oki thank you'

# %% [markdown]
# # get contacts dataframe

# %%
address_book_location = "/Users/joycehu/Library/Application Support/AddressBook/Sources/B470B8FA-DC30-4089-8B50-645AD77679C6/AddressBook-v22.abcddb"
conn_add = sqlite3.connect(address_book_location)
cursor = conn_add.cursor()


cursor.execute("SELECT DISTINCT ZABCDRECORD.ZFIRSTNAME [FIRST NAME], ZABCDRECORD.ZLASTNAME [LAST NAME], ZABCDPHONENUMBER.ZFULLNUMBER [FULL NUMBER] FROM ZABCDRECORD LEFT JOIN ZABCDPHONENUMBER ON ZABCDRECORD.Z_PK = ZABCDPHONENUMBER.ZOWNER ORDER BY ZABCDRECORD.ZLASTNAME, ZABCDRECORD.ZFIRSTNAME, ZABCDPHONENUMBER.ZORDERINGINDEX ASC")
result_set = cursor.fetchall()

result_set

contacts = pd.DataFrame(result_set, columns=['first', 'last', 'number'])
contacts
# Out:
#           first   last          number
# 0          None   None            None
# 1          None   None  (925) 818-8151
# 2          None   None  (925) 330-3093
# 3          None   None      5105851263
# 4          None   None  (408) 656-8727
# ..          ...    ...             ...
# 245      audrey    lee    +14088139475
# 246       katie  short  (513) 808-3540
# 247       ellie   wang    +17149320311
# 248      joanne    yen    +16263227484
# 249  Tony's Dad     王遠  (510) 386-0315
#
# [250 rows x 3 columns]

# %% [markdown]
# ## clean contacts df

# %%
'''
cleans numbers and puts them in the same format as numbers in handle df
'''
def standard_numbers(phone_number): 
    # remove all non-numeric characters
    numeric_number = re.sub(r'\D', '', phone_number)
    if len(numeric_number) == 10:
        numeric_number = "+1" + numeric_number
    if len(numeric_number) == 11:
        numeric_number = "+" + numeric_number
    return numeric_number
    
contacts = contacts.dropna(subset=['number'])
contacts['first'] = contacts['first'].fillna('')
contacts['last'] = contacts['last'].fillna('')
contacts['phone_number'] = contacts['number'].apply(standard_numbers)
contacts['full_name'] = contacts['first'] + ' ' + contacts['last']

contacts
# Out:
#           first   last          number  phone_number      full_name
# 1                       (925) 818-8151  +19258188151
# 2                       (925) 330-3093  +19253303093
# 3                           5105851263  +15105851263
# 4                       (408) 656-8727  +14086568727
# 5                           4085544790  +14085544790
# ..          ...    ...             ...           ...            ...
# 245      audrey    lee    +14088139475  +14088139475     audrey lee
# 246       katie  short  (513) 808-3540  +15138083540    katie short
# 247       ellie   wang    +17149320311  +17149320311     ellie wang
# 248      joanne    yen    +16263227484  +16263227484     joanne yen
# 249  Tony's Dad     王遠  (510) 386-0315  +15103860315  Tony's Dad 王遠
#
# [246 rows x 5 columns]

# %%
chats = pd.read_sql_query("select * from chat", conn)
chats.columns
# Out:
# Index(['ROWID', 'guid', 'style', 'state', 'account_id', 'properties',
#        'chat_identifier', 'service_name', 'room_name', 'account_login',
#        'is_archived', 'last_addressed_handle', 'display_name', 'group_id',
#        'is_filtered', 'successful_query', 'engram_id', 'server_change_token',
#        'ck_sync_state', 'last_read_message_timestamp', 'original_group_id',
#        'sr_server_change_token', 'sr_ck_sync_state', 'cloudkit_record_id',
#        'sr_cloudkit_record_id', 'last_addressed_sim_id', 'is_blackholed',
#        'syndication_date', 'syndication_type', 'is_recovered'],
#       dtype='object')

# %%
chats['original_group_id']
# Out:
# 0          4D683A63-8AA6-44E2-A41A-8CE229C6BD34
# 1          7307828C-B546-46A9-9066-A04C30E2F170
# 2          7E3B7DDE-51B0-46E8-8477-FA64B7C83C03
# 3          6B48FD96-D3FB-4B57-B87C-D52F29777F1C
# 4          F0AFF9C1-FB0D-4CA9-90E7-3E06BC815A3C
#                          ...
# 553    3F9D1FF94762D0C7EFEAB1F3DA4DDFEEE62B95CB
# 554        E9913812-1BA7-4D36-B538-92901E4E96E6
# 555    1302CFED824758B860627761992F24BC5665C1B1
# 556    3C5FC3EF333618151D37FEC3153F3364E9425CFC
# 557        CF625D97-6FB0-4C82-B772-B9A0CDFA3989
# Name: original_group_id, Length: 558, dtype: object

# %%
cur.execute(" select name from sqlite_master where type = 'table' ") 
for name in cur.fetchall():
    print(name)
# Out:
# ('_SqliteDatabaseProperties',)
# ('deleted_messages',)
# ('sqlite_sequence',)
# ('chat_handle_join',)
# ('chat_message_join',)
# ('message_attachment_join',)
# ('handle',)
# ('message',)
# ('chat',)
# ('attachment',)
# ('sync_deleted_messages',)
# ('message_processing_task',)
# ('sync_deleted_chats',)
# ('sync_deleted_attachments',)
# ('kvtable',)
# ('chat_recoverable_message_join',)
# ('unsynced_removed_recoverable_messages',)
# ('recoverable_message_part',)
# ('sqlite_stat1',)

# %%
mess = pd.read_sql_query("select * from chat_message_join", conn)
mess
# Out:
#         chat_id  message_id        message_date
# 0             1           1           567238093
# 1             1           2           567238246
# 2             2           3           567486800
# 3             2           4           567487648
# 4             3           5           567926776
# ...         ...         ...                 ...
# 171975      175      175935  725765478761323008
# 171976      175      175936  725765492567414528
# 171977      175      175937  725765601356318976
# 171978      175      175938  725765618502231936
# 171979        2      175939  725766475703421568
#
# [171980 rows x 3 columns]

# %%
chats['chat_identifier'].unique()
# Out:
# array(['+15107378796', '+15105094802', '+15107095002',
#        'chat901413911741755790', '+15107095003', '+16197464242',
#        'chat259784163111797896', 'chat62213516222744592', '+15103586597',
#        '+15108965703', '+15103648540', 'ballerina.eternity@gmail.com',
#        '+15103781127', '+15105650530', '+15103865875',
#        'beautyinsight@yahoo.com', '+19255884001', '+15105986378',
#        'chat19277881941239546', '+15105906719', '+15104588449',
#        'oceanhu@yahoo.com', '+15103333673', 'gingerhusunny@gmail.com',
#        '+15103869377', 'chat434284839447969', '+16034658370',
#        '+19072271391', 'chat175441370131602190', '+16034009217',
#        '+15309089745', '+17144964702', '+15103661021',
#        'chat262250114752797290', '+15103246580', 'chat358336207945331674',
#        '+16505565188', '+15106737668', '+15106406223',
#        'chat851910471287626308', 'chat972181684127495230', '+14128484593',
# ...

# %% [markdown]
# # get messages dataframe
#
# messages table: contains text messages and relevant info, stores the sender as handle_id
# handle table: contains "id" column that contains messager's phone number and corresponding handle_id as "ROWID"

# %%
messages.sort_values('handle_id')
# Out:
#         message_id                                               text  \
# 69916        71151                                              ohhhh
# 125569      126822                                          thats tru
# 125565      126818                    u guys were against it at first
# 125563      126816                         bro i can pull up recipets
# 125558      126811                         WHAT the board was my idea
# ...            ...                                                ...
# 172330      173617  <#>BofA: DO NOT share this code. We will NEVER...
# 172329      173616                                               None
# 172661      173948                                               None
# 173089      174376  Use this one-time activation code to enroll yo...
# 173435      174723  The USPS package has arrived at the warehouse ...
#
#         handle_id subject   service                date  is_audio_message  \
# ...

# %%
mess.columns
# Out:
# Index(['ROWID', 'guid', 'text', 'replace', 'service_center', 'handle_id',
#        'subject', 'country', 'attributedBody', 'version', 'type', 'service',
#        'account', 'account_guid', 'error', 'date', 'date_read',
#        'date_delivered', 'is_delivered', 'is_finished', 'is_emote',
#        'is_from_me', 'is_empty', 'is_delayed', 'is_auto_reply', 'is_prepared',
#        'is_read', 'is_system_message', 'is_sent', 'has_dd_results',
#        'is_service_message', 'is_forward', 'was_downgraded', 'is_archive',
#        'cache_has_attachments', 'cache_roomnames', 'was_data_detected',
#        'was_deduplicated', 'is_audio_message', 'is_played', 'date_played',
#        'item_type', 'other_handle', 'group_title', 'group_action_type',
#        'share_status', 'share_direction', 'is_expirable', 'expire_state',
#        'message_action_type', 'message_source', 'associated_message_guid',
#        'associated_message_type', 'balloon_bundle_id', 'payload_data',
# ...

# %%
mess = pd.read_sql_query("select * from message", conn)
mess
# Out:
#          ROWID                                  guid  \
# 0            1  B6E22420-1255-4642-9CAB-F646FC568C00
# 1            2  93F3F991-002E-43FB-B128-DA43F5D7ABC7
# 2            3  C62EB0E4-F138-4FE2-9220-8E656685DFC6
# 3            4  9957C675-F9D8-48B2-AAFD-BC2985E00942
# 4            5  D1AE6D88-2933-4820-AD4F-B2B39791A306
# ...        ...                                   ...
# 174647  175936  21C0F971-3545-4E02-8B45-007D9705D3CC
# 174648  175937  DADCC39D-D7AD-5357-20A0-2CC8D64AE5B0
# 174649  175938  907E6778-402D-4B98-A7CC-B7276711348B
# 174650  175939  753FC4C5-185C-407D-AE32-D1C794B683EA
# 174651  175940  FBEECDAE-8060-4B6F-8609-6820CBED5002
#
#                                                      text  replace  \
# 0       If haley send cc to my house over the next few...        0
# 1                                            Okok got it         0
# 2                                                    ￼￼￼￼        0
# ...

# %%
conn = sqlite3.connect('/Users/joycehu/Library/Messages/chat.db')
cur = conn.cursor()

# get handles df
handles = pd.read_sql_query("select * from handle", conn)
handles.head()
# Out:
#    ROWID            id country   service uncanonicalized_id  \
# 0      1  +15107378796      US  iMessage               None
# 1      2  +15105094802      US  iMessage               None
# 2      3  +15107095002      US  iMessage         5107095002
# 3      4  +15107095003      US  iMessage               None
# 4      5  +16197464242      US  iMessage               None
#
#                       person_centric_id
# 0  c1b59049-da23-476e-aebb-b2e812e48ace
# 1  695bc869-6313-4c1f-b0fe-b9ce9e748742
# 2  0d542d99-cbf5-4254-8c2c-0a929173c7da
# 3  5186b1b7-8016-41db-97d2-130f245f2415
# 4  a5322507-1b30-431d-9ce5-f379526e232a

# %%
messages.iloc[174649]['attributedBody']
# Out:
# b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84\x84\x84\x19NSMutableAttributedString\x00\x84\x84\x12NSAttributedString\x00\x84\x84\x08NSObject\x00\x85\x92\x84\x84\x84\x0fNSMutableString\x01\x84\x84\x08NSString\x01\x95\x84\x01+\x11ahh oki thank you\x86\x84\x02iI\x01\x11\x92\x84\x84\x84\x0cNSDictionary\x00\x95\x84\x01i\x01\x92\x84\x98\x98\x1d__kIMMessagePartAttributeName\x86\x92\x84\x84\x84\x08NSNumber\x00\x84\x84\x07NSValue\x00\x95\x84\x01*\x84\x9b\x9b\x00\x86\x86\x86'

# %%
# get messages

# rowid, text, handle_id, subject, service, date, date_read, date_delivered, is_audio_message, group_title
keep_cols = ['ROWID', 'text', 'attributedBody','handle_id', 'other_handle','subject', 'service', 'date', 'is_audio_message', 'group_title', 'is_sent','is_emote']

# Construct the SQL query with the specified columns
query = f'''
    SELECT {', '.join(keep_cols)},
           datetime(date/1000000000 + strftime("%s", "2001-01-01"), "unixepoch", "localtime") AS date_utc
    FROM message
'''

messages = pd.read_sql_query(query, conn)

# convert date to datetime 
messages
# Out:
#          ROWID                                               text  \
# 0            1  If haley send cc to my house over the next few...
# 1            2                                       Okok got it
# 2            3                                               ￼￼￼￼
# 3            4                                                 😉
# 4            5  https://spice.fsi.stanford.edu/fellowship/chin...
# ...        ...                                                ...
# 174647  175936                                               None
# 174648  175937  Something like, "in previous years praise team...
# 174649  175938                                               None
# 174650  175939                    How do you write a cover letter
# 174651  175940                                               None
#
#                                            attributedBody  handle_id  \
# 0       b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84...          1
# ...

# %%
# match handle_id to phone number 
messages.rename(columns={'ROWID' : 'message_id'}, inplace = True)
handles.rename(columns={'id' : 'phone_number', 'ROWID': 'handle_id'}, inplace = True)
merge_handle = pd.merge(messages[['text', 'attributedBody','handle_id', 'date_utc','subject', 'service','is_audio_message','group_title', 'message_id', 'is_sent','is_emote']],  handles[['handle_id', 'phone_number']], on ='handle_id', how='left')

merge_handle.head()
# Out:
#                                                 text  \
# 0  If haley send cc to my house over the next few...
# 1                                       Okok got it
# 2                                               ￼￼￼￼
# 3                                                 😉
# 4  https://spice.fsi.stanford.edu/fellowship/chin...
#
#                                       attributedBody  handle_id  \
# 0  b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84...          1
# 1  b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84...          1
# 2  b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84...          2
# 3  b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84...          2
# 4  b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84...          3
#
#               date_utc subject   service  is_audio_message group_title  \
# 0  2018-12-22 22:08:13    None  iMessage                 0        None
# 1  2018-12-22 22:10:46    None  iMessage                 0        None
# ...

# %%
# get the chat to message mapping
chat_message_joins = pd.read_sql_query("select * from chat_message_join", conn)
# and join back to the merge_level_1 table
chat_merge = pd.merge(merge_handle, chat_message_joins[['chat_id', 'message_id']], on = 'message_id', how='left')
chat_merge.head()
# Out:
#                                                 text  \
# 0  If haley send cc to my house over the next few...
# 1                                       Okok got it
# 2                                               ￼￼￼￼
# 3                                                 😉
# 4  https://spice.fsi.stanford.edu/fellowship/chin...
#
#                                       attributedBody  handle_id  \
# 0  b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84...          1
# 1  b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84...          1
# 2  b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84...          2
# 3  b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84...          2
# 4  b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84...          3
#
#               date_utc subject   service  is_audio_message group_title  \
# 0  2018-12-22 22:08:13    None  iMessage                 0        None
# 1  2018-12-22 22:10:46    None  iMessage                 0        None
# ...

# %%
'''
takes in encrypted attributedBody text and returns the decrypted string
'''
def convert_to_text(attributedBody):
    data = attributedBody
    typedstream.unarchive_from_data(data)

    # unarchive data
    unarchived_data = typedstream.unarchive_from_data(data)

    # access contents of GenericArchivedObject
    contents = unarchived_data.contents

    return contents[0].value.value

# %%
texts[texts['chat_id']==87]
# Out:
#                                      text  \
# 52552   thank goodness we have all apples
# 52555                                 yus
# 52557                                 yus
# 52558                                   ￼
# 52559                                   ￼
# ...                                   ...
# 107538                     ￼i neeko carry
# 107539                              shoot
# 107540                        they ff >:)
# 107767      all the schlumps be dating :o
# 107780                                :0
#
#                                            attributedBody  handle_id subject  \
# 52552   b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84...         82    None
# 52555   b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84...         88    None
# 52557   b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84...         87    None
# 52558   b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84...         83    None
# ...

# %%
texts[texts['attributedBody'].isna()]['chat_id'].value_counts()
# Out:
# 87.0     25
# 217.0    19
# 150.0    17
# 36.0     13
# 55.0     10
#          ..
# 57.0      1
# 30.0      1
# 38.0      1
# 27.0      1
# 544.0     1
# Name: chat_id, Length: 71, dtype: int64

# %%
# match phone number to sender name
texts = pd.merge(chat_merge, contacts, on ='phone_number', how='left')

# use 'name' if available, otherwise use 'phone_number'
texts['sender'] = texts['full_name'].fillna(texts['phone_number'])

# fixing issue where group titles don't always transfer 
texts['group_title'] = texts.groupby('chat_id')['group_title'].transform(lambda x: x.ffill().bfill())
# adding dates
texts['timestamp'] = texts['date_utc'].apply(lambda x: pd.Timestamp(x))
texts['date'] = texts['timestamp'].apply(lambda x: x.date())
texts['month'] = texts['timestamp'].apply(lambda x: int(x.month))
texts['year'] = texts['timestamp'].apply(lambda x: int(x.year))

# convert attributedBody text for text rows w/ na


# clean df
drop_cols = ['first', 'last', 'full_name', 'number', 'date_utc']
texts = texts.drop(drop_cols, axis=1)


texts.head()
# Out:
#                                                 text  \
# 0  If haley send cc to my house over the next few...
# 1                                       Okok got it
# 2                                               ￼￼￼￼
# 3                                                 😉
# 4  https://spice.fsi.stanford.edu/fellowship/chin...
#
#                                       attributedBody  handle_id subject  \
# 0  b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84...          1    None
# 1  b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84...          1    None
# 2  b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84...          2    None
# 3  b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84...          2    None
# 4  b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84...          3    None
#
#     service  is_audio_message group_title  message_id  is_sent  is_emote  \
# 0  iMessage                 0        None           1        1         0
# ...

# %% [markdown]
# # analysis !
#
# - top 5 ppl i text all time
# - top 5 this month
# - top 5 this year
# - ppl i text the most
# - ppl who texts me the most\

# %%
'''
get the top 5 people you text of all time
'''
def all_time():
    all_time = texts.groupby('handle_id').count().sort_values('is_sent', ascending=False)
# Out:
# '\nget the top 5 people you text of all time\n'

# %%
texts[texts['handle_id'] == 4]
# Out:
#                   text  handle_id subject   service  is_audio_message  \
# 11          到了，很好，小心開車          4    None  iMessage                 0
# 13            慢慢開，想到就累          4    None  iMessage                 0
# 15                 睡覺吧          4    None  iMessage                 0
# 18            Ok. 再看看吧          4    None  iMessage                 0
# 19              要去C&L           4    None  iMessage                 0
# ...                ...        ...     ...       ...               ...
# 174088              有吧          4    None  iMessage                 0
# 174209            None          4    None  iMessage                 0
# 174225            None          4    None  iMessage                 0
# 174306  Liked an image          4    None  iMessage                 0
# 174307    So don’t go😆          4    None  iMessage                 0
#
#                       group_title  message_id  is_sent  phone_number  chat_id  \
# ...

# %%
this_year = texts[(texts['year'] == 2023)]
this_year.groupby('handle_id').count().sort_values('text', ascending= False)
# Out:
#             text  subject  service  is_audio_message  group_title  message_id  \
# handle_id
# 508        13141        0    14454             14454            0       14454
# 2           3068        1     3193              3193         1042        3193
# 0           1372        0     1468              1468         1159        1468
# 59          1372        0     1409              1409          354        1409
# 129         1247        0     1901              1901            0        1901
# ...          ...      ...      ...               ...          ...         ...
# 20             0        0        1                 1            0           1
# 711            0        0        1                 1            0           1
# 405            0        0        1                 1            0           1
# 715            0        0        1                 1            0           1
# 694            0        0        1                 1            0           1
#
# ...

# %%
this_month = texts[(texts['year'] == 2023) & (texts['month'] == 12)]
this_month.groupby('handle_id').count().sort_values('text', ascending= False)
# Out:
#            text  subject  service  is_audio_message  group_title  message_id  \
# handle_id
# 508         807        0     1270              1270            0        1270
# 129         533        0      924               924            0         924
# 2           287        0      369               369           60         369
# 4            83        0       87                87           85          87
# 0            51        0       81                81           67          81
# 599          38        0       59                59            5          59
# 3            38        0       38                38           38          38
# 698          36        0       36                36           36          36
# 376          27        0       28                28            0          28
# 690          27        0       31                31            0          31
# 169          26        0       43                43            0          43
# ...

# %%
texts.groupby('handle_id').count().sort_values('is_sent', ascending=False)
# Out:
#             text  subject  service  is_audio_message  group_title  message_id  \
# handle_id
# 59         37780        7    37831             37831          486       37831
# 508        20023        1    21337             21337            0       21337
# 23         12957        0    12965             12965          890       12965
# 99          9647        0     9751              9751         4934        9751
# 0           9158        0     9576              9576         7310        9576
# ...          ...      ...      ...               ...          ...         ...
# 488            1        0        1                 1            0           1
# 489            1        0        1                 1            0           1
# 491            1        0        1                 1            0           1
# 494            1        0        1                 1            0           1
# 717            1        0        1                 1            0           1
#
# ...

# %%
all_time = texts.groupby('handle_id').count().sort_values('is_sent', ascending=False)
top_5 = all_time.iloc[0:5].reset_index()['handle_id'].to_list()
for handle_id in top_5:
    print(texts[texts['handle_id'] == handle_id].iloc[0]['sender'])
# Out:
# Hezzy Crawford
# Micah Barreyro
# Anannya Deshmukh
# Yolanda Mai
# nan

# %%
handles
# Out:
#      handle_id            phone_number country   service uncanonicalized_id  \
# 0            1            +15107378796      US  iMessage               None
# 1            2            +15105094802      US  iMessage               None
# 2            3            +15107095002      US  iMessage         5107095002
# 3            4            +15107095003      US  iMessage               None
# 4            5            +16197464242      US  iMessage               None
# ..         ...                     ...     ...       ...                ...
# 708        713            +18773124302      US       SMS       +18773124302
# 709        714                   41021      US       SMS              41021
# 710        715            +18772319448      US       SMS       +18772319448
# 711        716                   60969      US       SMS              60969
# 712        717  leop1nunez@hotmail.com      US  iMessage               None
#
#                         person_centric_id
# ...

# %%
handles[handles['handle_id'] == 0]
# Out:
# Empty DataFrame
# Columns: [handle_id, phone_number, country, service, uncanonicalized_id, person_centric_id]
# Index: []

# %%
texts[texts['handle_id'] == 0]#.iloc[0]['sender']
# Out:
#                         text  handle_id subject   service  is_audio_message  \
# 245            我今天就不要去track了          0    None  iMessage                 0
# 255                     None          0    None  iMessage                 0
# 256                     None          0    None  iMessage                 0
# 257                     None          0    None  iMessage                 0
# 258                     None          0    None  iMessage                 0
# ...                      ...        ...     ...       ...               ...
# 174482  MY NESPRESSO IS HERE          0    None  iMessage                 0
# 174484                  nono          0    None  iMessage                 0
# 174485                i open          0    None  iMessage                 0
# 174505                  None          0    None       SMS                 0
# 174506                  None          0    None       SMS                 0
#
# ...

# %%
texts[texts['chat_id'] == 36]
# Out:
#                                               text  handle_id  \
# 4612                      ￼The Monarch Cave Ruins           3
# 4965    My package is in the mailbox please get it          2
# 4966                                             ￼          3
# 4967                                           Yay          2
# 5137                                             ￼          0
# ...                                            ...        ...
# 174314                                         yes          3
# 174482                        MY NESPRESSO IS HERE          0
# 174483          I took it. Can I open it? Mileage?          3
# 174484                                        nono          0
# 174485                                      i open          0
#
#                    date_utc subject   service  is_audio_message group_title  \
# 4612    2019-08-24 12:14:04    None  iMessage                 0        None
# ...

# %%
texts[texts['group_title'] == 'everyone should come home']
# Out:
#                                               text  handle_id  \
# 4612                      ￼The Monarch Cave Ruins           3
# 4965    My package is in the mailbox please get it          2
# 4966                                             ￼          3
# 4967                                           Yay          2
# 5137                                             ￼          0
# ...                                            ...        ...
# 174314                                         yes          3
# 174482                        MY NESPRESSO IS HERE          0
# 174483          I took it. Can I open it? Mileage?          3
# 174484                                        nono          0
# 174485                                      i open          0
#
#                    date_utc subject   service  is_audio_message  \
# 4612    2019-08-24 12:14:04    None  iMessage                 0
# 4965    2019-09-04 12:00:47    None  iMessage                 0
# ...

# %%
texts['group_title'].isna().sum()
# Out:
# 174623

# %%
texts['group_title'].isna().sum()
# Out:
# 135961

# %%
texts['group_title'] = texts.groupby('chat_id')['group_title'].transform(lambda x: x.ffill().bfill())
texts
# Out:
#                                                      text  handle_id  \
# 0       If haley send cc to my house over the next few...          1
# 1                                            Okok got it           1
# 2                                                    ￼￼￼￼          2
# 3                                                      😉           2
# 4       https://spice.fsi.stanford.edu/fellowship/chin...          3
# ...                                                   ...        ...
# 174677                                               None        167
# 174678                                               None        167
# 174679  Something like, "in previous years praise team...        167
# 174680                                               None        167
# 174681                    How do you write a cover letter          2
#
#                    date_utc subject   service  is_audio_message group_title  \
# ...
